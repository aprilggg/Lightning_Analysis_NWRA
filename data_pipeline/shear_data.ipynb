# %% [markdown]
# # Shear Data
# This dataset is necessary for rainband lightning burst detection.

# %%
import os
import glob
import pandas as pd
import polars as pl
from scipy.io import loadmat
import numpy as np

# %% [markdown]
# We start by importing the filtered trackfile data to extract a list of unique storm codes for storms category 1 or higher. We use this to limit the shear files we process to streamline the process and reduce the workload.

# %%
# Import the filtered trackfile for the list of storm codes in analysis
trackfile = pd.read_csv("../data/Filtered_Reduced_Trackfile.csv")
tc_list = trackfile[["storm_code", "storm_name"]].drop_duplicates()
tc_list.reset_index(drop=True, inplace=True)
tc_list.head()
# Out:
#   storm_code  storm_name
# 0  ATL_20_28        Zeta
# 1  ATL_20_28  Twenty-Eig
# 2  SHEM_20_4       Sarai
# 3  SHEM_16_7      Victor
# 4   ATL_17_8        Gert

# %%
# Export filtered TC list for later use
tc_list.to_csv("filtered_tc_list.csv", index=False)

# %%
# Restart kernel and import unique value csv
tc_list = pd.read_csv("tc_list.csv")

# %% [markdown]
# Using the storm codes, we look for each TC's shear file in the base path (refers to thumb drive). If the TC has a shear file, we append it to the dataframe. We drop rows with null shear values.

# %%
# Define base path and list of storm codes
base_path = "/mnt/d/WWLLN_TC_Data_2010_2020/"
storm_codes = tc_list["storm_code"]

# %%
# List to store data efficiently
data_list = []
processed_storms = []

# Process each storm code
for storm_code in storm_codes:
    if storm_code in processed_storms:
        continue
    basin, year, number = storm_code.split("_")
    folder_path = os.path.join(base_path, year, basin, number)
    file_pattern = os.path.join(folder_path, "*_Intensity_Shear.mat")
    files = glob.glob(file_pattern)

    if files:
        filename = files[0]  # Pick the first matching file
        mat_data = loadmat(filename)

        # Print keys to inspect the structure
        print(f"Loaded file: {filename}")

        # Create a DataFrame
        if 'cg_IntenShear' in mat_data:
            data_array = mat_data['cg_IntenShear']
            # Convert NumPy array to a Polars DataFrame directly
            df_temp = pd.DataFrame(data_array, columns=['year', 'month', 'day', 'hour', 'min', 'second', 'lat',
              'long', 'distance_east', 'distance_north', 'category', 'intensity_change',
              'trackfile_id', 'shear_magnitude', 'shear_angle'])
            # Drop NaN (null) rows before appending
            df_temp = df_temp.dropna()
            # Add a new column for storm_code
            df_temp["storm_code"] = storm_code
            data_list.append(df_temp)
        else:
            print("Variable not found in .mat file")
    else:
        print(f"{storm_code} does not have a shear file.")

# Efficiently concatenate all Polars DataFrames
shear_data = pd.concat(data_list, ignore_index=True)
# Out:
# ATL_20_28 does not have a shear file.
# ATL_20_28 does not have a shear file.
# SHEM_20_4 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/16/SHEM/7/VictorWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/17/ATL/8/GertWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/13/WPAC/12/TramiWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/16/ATL/5/EarlWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/15/WPAC/6/NoulWWLLN_Intensity_Shear.mat
# WPAC_18_15 does not have a shear file.
# SHEM_19_6 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/10/ATL/13/KarlWWLLN_Intensity_Shear.mat
# WPAC_18_22 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/14/ATL/7/FayWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/17/SHEM/15/ErnieWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/15/IO/4/ChapalaWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/11/SHEM/8/WilmaWWLLN_Intensity_Shear.mat
# IO_18_6 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/17/WPAC/27/SaolaWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/14/EPAC/7/GenevieveWWLLN_Intensity_Shear.mat
# SHEM_18_9 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/12/WPAC/5/GucholWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/12/WPAC/15/TembinWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/16/EPAC/13/LesterWWLLN_Intensity_Shear.mat
# WPAC_19_9 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/14/SHEM/8/ColinWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/16/EPAC/20/SeymourWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/13/SHEM/16/HarunaWWLLN_Intensity_Shear.mat
# EPAC_20_18 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/16/WPAC/26/MeariWWLLN_Intensity_Shear.mat
# SHEM_20_7 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/10/ATL/7/EarlWWLLN_Intensity_Shear.mat
# CPAC_15_7 does not have a shear file.
# ATL_19_2 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/12/EPAC/16/PaulWWLLN_Intensity_Shear.mat
# WPAC_19_20 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/10/ATL/21/TomasWWLLN_Intensity_Shear.mat
# WPAC_19_22 does not have a shear file.
# ATL_20_31 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/10/ATL/11/IgorWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/17/SHEM/18/DonnaWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/15/EPAC/9/GuillermoWWLLN_Intensity_Shear.mat
# EPAC_20_12 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/14/WPAC/8/NeoguriWWLLN_Intensity_Shear.mat
# ATL_20_16 does not have a shear file.
# CPAC_14_2 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/11/SHEM/7/ZeliaWWLLN_Intensity_Shear.mat
# SHEM_20_2 does not have a shear file.
# WPAC_19_19 does not have a shear file.
# WPAC_19_29 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/13/SHEM/17/RustyWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/13/SHEM/3/ClaudiaWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/10/SHEM/3/CleoWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/10/ATL/14/LisaWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/10/SHEM/1/AnjaWWLLN_Intensity_Shear.mat
# WPAC_18_26 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/16/EPAC/16/OrleneWWLLN_Intensity_Shear.mat
# SHEM_19_20 does not have a shear file.
# WPAC_18_33 does not have a shear file.
# SHEM_19_18 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/14/WPAC/3/FaxaiWWLLN_Intensity_Shear.mat
# CPAC_15_4 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/15/WPAC/11/NangkaWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/10/ATL/12/JuliaWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/17/WPAC/24/KhanunWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/10/WPAC/11/MerantiWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/13/SHEM/10/GarryWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/12/WPAC/17/SanbaWWLLN_Intensity_Shear.mat
# SHEM_18_7 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/11/IO/6/ThaneWWLLN_Intensity_Shear.mat
# SHEM_18_15 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/14/SHEM/24/JackWWLLN_Intensity_Shear.mat
# WPAC_18_31 does not have a shear file.
# SHEM_20_15 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/16/SHEM/15/EmeraudeWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/10/WPAC/12/FanapiWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/16/IO/5/VardahWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/16/WPAC/6/NidaWWLLN_Intensity_Shear.mat
# WPAC_18_3 does not have a shear file.
# EPAC_19_11 does not have a shear file.
# ATL_20_20 does not have a shear file.
# ATL_20_20 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/15/WPAC/24/KoppuWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/13/SHEM/22/VictoriaWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/16/EPAC/7/FrankWWLLN_Intensity_Shear.mat
# WPAC_19_11 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/11/EPAC/3/CalvinWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/17/SHEM/17/FrancesWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/10/WPAC/4/ChanthuWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/13/WPAC/24/NariWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/16/WPAC/2/NepartakWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/16/EPAC/19/UlikaWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/15/WPAC/20/KrovanhWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/16/EPAC/14/MadelineWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/12/SHEM/12/GiovannaWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/15/ATL/11/JoaquinWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/15/WPAC/22/MujigaeWWLLN_Intensity_Shear.mat
# IO_19_2 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/12/ATL/13/MichaelWWLLN_Intensity_Shear.mat
# WPAC_20_25 does not have a shear file.
# SHEM_18_12 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/13/IO/6/MadiWWLLN_Intensity_Shear.mat
# WPAC_20_22 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/12/WPAC/12/HaikuiWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/10/WPAC/13/MalakasWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/12/ATL/12/LeslieWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/15/ATL/6/FredWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/14/ATL/8/GonzaloWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/15/EPAC/2/BlancaWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/10/IO/4/GiriWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/13/EPAC/5/ErickWWLLN_Intensity_Shear.mat
# ATL_18_13 does not have a shear file.
# SHEM_20_5 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/13/EPAC/2/BarbaraWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/15/IO/5/MeghWWLLN_Intensity_Shear.mat
# ATL_18_9 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/12/WPAC/4/MawarWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/15/SHEM/19/OlwynWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/15/ATL/4/DannyWWLLN_Intensity_Shear.mat
# EPAC_18_14 does not have a shear file.
# WPAC_18_10 does not have a shear file.
# EPAC_20_8 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/17/EPAC/16/MaxWWLLN_Intensity_Shear.mat
# WPAC_19_24 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/15/SHEM/12/LamWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/11/ATL/14/MariaWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/13/EPAC/17/RaymondWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/16/WPAC/24/SarikaWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/10/SHEM/21/ImaniWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/14/SHEM/17/GillianWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/17/WPAC/28/DamreyWWLLN_Intensity_Shear.mat
# IO_20_1 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/17/WPAC/15/HatoWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/15/WPAC/1/MekkhalaWWLLN_Intensity_Shear.mat
# WPAC_20_21 does not have a shear file.
# SHEM_20_22 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/14/ATL/1/ArthurWWLLN_Intensity_Shear.mat
# ATL_19_9 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/16/SHEM/19/FantalaWWLLN_Intensity_Shear.mat
# WPAC_19_28 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/13/WPAC/28/LekimaWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/15/WPAC/9/Chan-homWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/12/SHEM/17/LuaWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/10/SHEM/19/TomasWWLLN_Intensity_Shear.mat
# EPAC_18_12 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/10/WPAC/15/MegiWWLLN_Intensity_Shear.mat
# EPAC_18_24 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/15/EPAC/22/SandraWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/10/SHEM/12/OliWWLLN_Intensity_Shear.mat
# SHEM_18_21 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/14/IO/3/HudhudWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/10/WPAC/3/ConsonWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/11/WPAC/22/NalgaeWWLLN_Intensity_Shear.mat
# ATL_20_13 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/17/ATL/17/OpheliaWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/15/SHEM/13/MarciaWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/12/SHEM/4/BenildeWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/16/WPAC/16/MerantiWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/16/ATL/9/HermineWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/10/EPAC/9/FrankWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/11/WPAC/4/SongdaWWLLN_Intensity_Shear.mat
# WPAC_18_25 does not have a shear file.
# IO_13_5 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/17/IO/3/OckhiWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/15/WPAC/13/SoudelorWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/12/ATL/17/RafaelWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/11/EPAC/2/BeatrizWWLLN_Intensity_Shear.mat
# EPAC_18_3 does not have a shear file.
# WPAC_18_9 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/15/WPAC/2/HigosWWLLN_Intensity_Shear.mat
# WPAC_20_9 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/11/EPAC/7/GregWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/10/IO/5/JalWWLLN_Intensity_Shear.mat
# SHEM_20_16 does not have a shear file.
# EPAC_19_1 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/17/ATL/12/JoseWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/15/EPAC/10/HildaWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/11/EPAC/11/IrwinWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/13/SHEM/13/FellengWWLLN_Intensity_Shear.mat
# SHEM_19_24 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/17/ATL/11/IrmaWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/17/ATL/9/HarveyWWLLN_Intensity_Shear.mat
# EPAC_18_20 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/12/SHEM/10/JasmineWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/14/WPAC/10/MatmoWWLLN_Intensity_Shear.mat
# IO_19_1 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/13/WPAC/23/DanasWWLLN_Intensity_Shear.mat
# WPAC_20_3 does not have a shear file.
# WPAC_20_3 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/14/SHEM/15/GuitoWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/13/EPAC/7/GilWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/15/EPAC/15/LindaWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/17/ATL/7/FranklinWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/13/WPAC/7/SoulikWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/12/SHEM/7/EthelWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/10/SHEM/20/UluiWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/12/ATL/11/KirkWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/15/EPAC/20/PatriciaWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/12/EPAC/9/IleanaWWLLN_Intensity_Shear.mat
# SHEM_18_6 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/13/WPAC/17/UsagiWWLLN_Intensity_Shear.mat
# IO_19_5 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/17/WPAC/14/BanyanWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/16/ATL/7/GastonWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/14/ATL/6/EdouardWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/12/EPAC/3/CarlottaWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/14/SHEM/21/HellenWWLLN_Intensity_Shear.mat
# WPAC_18_28 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/14/SHEM/18/LusiWWLLN_Intensity_Shear.mat
# IO_18_2 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/17/ATL/15/MariaWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/11/ATL/9/IreneWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/14/ATL/4/CristobalWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/11/EPAC/5/EugeneWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/12/ATL/3/ChrisWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/10/ATL/1/AlexWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/14/WPAC/18/PhanfoneWWLLN_Intensity_Shear.mat
# EPAC_18_7 does not have a shear file.
# ATL_19_13 does not have a shear file.
# IO_20_4 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/13/SHEM/15/GinoWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/10/IO/1/LailaWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/14/IO/4/NilofarWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/12/SHEM/1/AlengaWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/11/SHEM/10/BiancaWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/11/SHEM/15/CarlosWWLLN_Intensity_Shear.mat
# IO_19_3 does not have a shear file.
# IO_19_4 does not have a shear file.
# ATL_19_18 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/17/ATL/16/NateWWLLN_Intensity_Shear.mat
# SHEM_18_4 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/13/WPAC/25/WiphaWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/11/WPAC/18/RokeWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/10/SHEM/14/PatWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/10/WPAC/16/ChabaWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/16/SHEM/11/WinstonWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/10/EPAC/4/CeliaWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/15/WPAC/28/MelorWWLLN_Intensity_Shear.mat
# EPAC_19_2 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/16/WPAC/12/LionrockWWLLN_Intensity_Shear.mat
# WPAC_20_10 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/14/EPAC/9/IselleWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/14/WPAC/15/KalmaegiWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/11/WPAC/10/Nock-tenWWLLN_Intensity_Shear.mat
# WPAC_20_11 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/13/EPAC/4/DalilaWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/16/EPAC/5/DarbyWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/12/WPAC/11/DamreyWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/13/WPAC/20/WutipWWLLN_Intensity_Shear.mat
# ATL_20_27 does not have a shear file.
# EPAC_18_21 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/17/WPAC/7/NoruWWLLN_Intensity_Shear.mat
# EPAC_19_7 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/12/WPAC/16/BolavenWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/10/SHEM/16/GelaneWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/12/ATL/9/IsaacWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/17/ATL/14/LeeWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/10/ATL/20/SharyWWLLN_Intensity_Shear.mat
# WPAC_19_27 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/16/ATL/15/NicoleWWLLN_Intensity_Shear.mat
# SHEM_19_3 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/14/EPAC/11/KarinaWWLLN_Intensity_Shear.mat
# SHEM_19_17 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/10/ATL/19/RichardWWLLN_Intensity_Shear.mat
# WPAC_18_30 does not have a shear file.
# SHEM_19_16 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/12/WPAC/10/SaolaWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/17/WPAC/17/SanvuWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/12/EPAC/12/LaneWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/15/EPAC/1/AndresWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/14/EPAC/18/RachelWWLLN_Intensity_Shear.mat
# ATL_19_19 does not have a shear file.
# WPAC_19_14 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/11/EPAC/4/DoraWWLLN_Intensity_Shear.mat
# IO_20_2 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/13/WPAC/29/KrosaWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/15/EPAC/12/IgnacioWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/13/ATL/10/IngridWWLLN_Intensity_Shear.mat
# SHEM_19_15 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/12/WPAC/24/Son-tinhWWLLN_Intensity_Shear.mat
# SHEM_18_11 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/16/EPAC/4/CeliaWWLLN_Intensity_Shear.mat
# SHEM_18_10 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/15/WPAC/23/Choi-wanWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/17/ATL/13/KatiaWWLLN_Intensity_Shear.mat
# WPAC_20_15 does not have a shear file.
# WPAC_20_15 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/11/WPAC/20/NesatWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/15/SHEM/22/JoalaneWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/10/SHEM/8/MagdaWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/15/WPAC/17/AtsaniWWLLN_Intensity_Shear.mat
# SHEM_20_1 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/13/SHEM/19/SandraWWLLN_Intensity_Shear.mat
# CPAC_15_1 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/15/ATL/12/KateWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/14/ATL/3/BerthaWWLLN_Intensity_Shear.mat
# IO_18_7 does not have a shear file.
# SHEM_20_14 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/15/SHEM/17/PamWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/15/SHEM/21/IkolaWWLLN_Intensity_Shear.mat
# ATL_20_26 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/17/SHEM/16/CookWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/15/EPAC/13/JimenaWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/15/WPAC/21/DujuanWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/12/EPAC/4/DanielWWLLN_Intensity_Shear.mat
# ATL_20_29 does not have a shear file.
# ATL_20_29 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/16/SHEM/18/ZenaWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/17/WPAC/21/DoksuriWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/12/WPAC/26/BophaWWLLN_Intensity_Shear.mat
# WPAC_20_7 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/16/SHEM/6/UlaWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/10/IO/3/PhetWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/14/WPAC/19/VongfongWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/15/EPAC/3/CarlosWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/14/SHEM/7/IanWWLLN_Intensity_Shear.mat
# WPAC_19_2 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/15/WPAC/16/GoniWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/17/WPAC/20/TalimWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/17/EPAC/9/HilaryWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/14/WPAC/11/HalongWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/11/ATL/16/OpheliaWWLLN_Intensity_Shear.mat
# SHEM_19_25 does not have a shear file.
# ATL_18_2 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/11/ATL/17/PhilippeWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/11/EPAC/9/HilaryWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/10/ATL/6/DanielleWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/12/EPAC/7/GilmaWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/12/SHEM/9/IggyWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/15/WPAC/25/ChampiWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/16/EPAC/17/PaineWWLLN_Intensity_Shear.mat
# WPAC_19_21 does not have a shear file.
# ATL_18_6 does not have a shear file.
# WPAC_20_19 does not have a shear file.
# SHEM_19_7 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/11/SHEM/17/AtuWWLLN_Intensity_Shear.mat
# ATL_20_19 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/16/SHEM/13/UriahWWLLN_Intensity_Shear.mat
# SHEM_18_3 does not have a shear file.
# SHEM_20_8 does not have a shear file.
# SHEM_19_23 does not have a shear file.
# EPAC_18_10 does not have a shear file.
# SHEM_19_19 does not have a shear file.
# SHEM_18_20 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/16/WPAC/20/MegiWWLLN_Intensity_Shear.mat
# IO_20_3 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/12/WPAC/3/SanvuWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/16/ATL/1/AlexWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/15/EPAC/19/OlafWWLLN_Intensity_Shear.mat
# EPAC_18_16 does not have a shear file.
# ATL_18_14 does not have a shear file.
# CPAC_16_1 does not have a shear file.
# SHEM_19_12 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/15/WPAC/27/In-faWWLLN_Intensity_Shear.mat
# IO_12_6 does not have a shear file.
# EPAC_19_13 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/16/WPAC/30/Nock-tenWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/16/EPAC/22/OttoWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/13/WPAC/31/HaiyanWWLLN_Intensity_Shear.mat
# ATL_19_5 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/13/SHEM/23/ZaneWWLLN_Intensity_Shear.mat
# ATL_20_8 does not have a shear file.
# WPAC_18_17 does not have a shear file.
# WPAC_18_17 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/10/SHEM/23/RobynWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/12/SHEM/8/FunsoWWLLN_Intensity_Shear.mat
# SHEM_18_16 does not have a shear file.
# SHEM_19_13 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/11/EPAC/10/JovaWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/14/WPAC/6/TapahWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/17/SHEM/19/EllaWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/17/WPAC/33/TembinWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/16/WPAC/25/HaimaWWLLN_Intensity_Shear.mat
# EPAC_18_17 does not have a shear file.
# SHEM_19_5 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/17/SHEM/9/EnawoWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/11/SHEM/11/YasiWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/16/WPAC/23/SongdaWWLLN_Intensity_Shear.mat
# WPAC_20_1 does not have a shear file.
# EPAC_18_2 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/15/SHEM/9/EuniceWWLLN_Intensity_Shear.mat
# WPAC_19_25 does not have a shear file.
# EPAC_19_6 does not have a shear file.
# EPAC_19_15 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/16/WPAC/21/ChabaWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/14/WPAC/20/NuriWWLLN_Intensity_Shear.mat
# SHEM_19_11 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/13/SHEM/7/DumileWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/10/SHEM/15/ReneWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/12/WPAC/22/PrapiroonWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/17/SHEM/13/DebbieWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/15/WPAC/4/MaysakWWLLN_Intensity_Shear.mat
# CPAC_13_1 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/11/WPAC/8/Ma-onWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/16/SHEM/9/StanWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/15/SHEM/1/AdjaliWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/13/SHEM/21/ImeldaWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/15/SHEM/18/NathanWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/12/ATL/18/SandyWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/12/ATL/8/GordonWWLLN_Intensity_Shear.mat
# WPAC_18_14 does not have a shear file.
# ATL_18_3 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/16/EPAC/8/GeorgetteWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/13/ATL/9/HumbertoWWLLN_Intensity_Shear.mat
# SHEM_20_3 does not have a shear file.
# WPAC_18_34 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/12/WPAC/18/JelawatWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/10/ATL/17/OttoWWLLN_Intensity_Shear.mat
# ATL_18_8 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/15/SHEM/24/QuangWWLLN_Intensity_Shear.mat
# EPAC_20_9 does not have a shear file.
# WPAC_19_10 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/13/EPAC/3/CosmeWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/11/ATL/18/RinaWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/17/WPAC/25/LanWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/13/WPAC/6/RumbiaWWLLN_Intensity_Shear.mat
# WPAC_20_16 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/10/SHEM/6/LaurenceWWLLN_Intensity_Shear.mat
# WPAC_18_23 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/16/WPAC/15/NamtheunWWLLN_Intensity_Shear.mat
# SHEM_20_20 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/13/EPAC/8/HenrietteWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/11/EPAC/1/AdrianWWLLN_Intensity_Shear.mat
# ATL_20_17 does not have a shear file.
# IO_18_5 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/12/WPAC/14/Kai-takWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/15/SHEM/10/OlaWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/16/EPAC/15/NewtonWWLLN_Intensity_Shear.mat
# WPAC_19_26 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/13/SHEM/8/NarelleWWLLN_Intensity_Shear.mat
# SHEM_20_25 does not have a shear file.
# SHEM_20_24 does not have a shear file.
# ATL_20_14 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/13/WPAC/26/FranciscoWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/16/EPAC/3/BlasWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/10/SHEM/22/PaulWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/16/SHEM/8/CorentinWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/14/WPAC/9/RammasunWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/13/WPAC/11/UtorWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/13/EPAC/13/ManuelWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/10/SHEM/7/EdzaniWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/17/SHEM/5/DineoWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/15/EPAC/5/DoloresWWLLN_Intensity_Shear.mat
# ATL_18_16 does not have a shear file.
# SHEM_19_22 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/14/WPAC/22/HagupitWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/12/EPAC/6/FabioWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/15/EPAC/17/MartyWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/11/WPAC/11/MuifaWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/16/SHEM/20/AmosWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/11/SHEM/16/DianneWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/11/SHEM/19/BuneWWLLN_Intensity_Shear.mat
# CPAC_18_1 does not have a shear file.
# WPAC_19_23 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/16/WPAC/18/MalakasWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/14/SHEM/23/ItaWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/12/WPAC/9/VicenteWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/13/WPAC/19/PabukWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/13/WPAC/22/FitowWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/10/ATL/18/PaulaWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/12/WPAC/2/PakharWWLLN_Intensity_Shear.mat
# ATL_19_10 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/11/WPAC/12/MerbokWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/15/SHEM/4/KateWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/12/SHEM/16/KojiWWLLN_Intensity_Shear.mat
# WPAC_18_19 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/17/WPAC/11/NesatWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/15/WPAC/10/LinfaWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/11/EPAC/13/KennethWWLLN_Intensity_Shear.mat
# WPAC_19_15 does not have a shear file.
# SHEM_19_21 does not have a shear file.
# EPAC_18_15 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/16/ATL/16/OttoWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/12/ATL/14/NadineWWLLN_Intensity_Shear.mat
# SHEM_18_19 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/11/WPAC/14/NanmadolWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/12/ATL/5/ErnestoWWLLN_Intensity_Shear.mat
# ATL_20_9 does not have a shear file.
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/11/ATL/12/KatiaWWLLN_Intensity_Shear.mat
# Loaded file: /mnt/d/WWLLN_TC_Data_2010_2020/17/SHEM/4/CarlosWWLLN_Intensity_Shear.mat

# %%
# Display the final DataFrame
shear_data.head()
# Out:
#      year  month   day  hour  min  second     lat      long  distance_east  \
# 0  2016.0    1.0  14.0   3.0  0.0  6.4994 -7.2386 -170.1965       -591.885
# 1  2016.0    1.0  14.0   3.0  0.0  6.6831 -7.1552 -170.2882       -602.111
# 2  2016.0    1.0  14.0   3.0  0.0  6.8064 -7.2494 -170.2057       -592.885
# 3  2016.0    1.0  14.0   3.0  0.0  6.9387 -7.2733 -170.1481       -586.501
# 4  2016.0    1.0  14.0   3.0  0.0  6.7190 -7.2224 -170.1888       -591.057
#
#    distance_north  category  intensity_change  trackfile_id  shear_magnitude  \
# 0         623.735       0.0               1.0         121.0            221.0
# 1         633.008       0.0               1.0         121.0            221.0
# 2         622.534       0.0               1.0         121.0            221.0
# 3         619.876       0.0               1.0         121.0            221.0
# 4         625.536       0.0               1.0         121.0            221.0
#
#    shear_angle storm_code
# 0        147.0  SHEM_16_7
# 1        147.0  SHEM_16_7
# 2        147.0  SHEM_16_7
# 3        147.0  SHEM_16_7
# 4        147.0  SHEM_16_7

# %%
len(shear_data)
# Out:
# 29726435

# %% [markdown]
# We export the unbinned shear data for future reference.

# %%
# Export the unbinned shear data as a tab-separated txt file
shear_data.to_csv("unbinned_shear_data.txt", sep="\t", index=False)

# %% [markdown]
# We can restart the kernel here and read in the data again to free up space.

# %%
# Import file
shear_data = pl.read_csv("unbinned_shear_data.txt", separator="\t")

# %%
shear_data.head(20)
# Out:
# shape: (20, 16)
# ┌────────┬───────┬──────┬──────┬───┬──────────────┬─────────────────┬─────────────┬────────────┐
# │ year   ┆ month ┆ day  ┆ hour ┆ … ┆ trackfile_id ┆ shear_magnitude ┆ shear_angle ┆ storm_code │
# │ ---    ┆ ---   ┆ ---  ┆ ---  ┆   ┆ ---          ┆ ---             ┆ ---         ┆ ---        │
# │ f64    ┆ f64   ┆ f64  ┆ f64  ┆   ┆ f64          ┆ f64             ┆ f64         ┆ str        │
# ╞════════╪═══════╪══════╪══════╪═══╪══════════════╪═════════════════╪═════════════╪════════════╡
# │ 2016.0 ┆ 1.0   ┆ 14.0 ┆ 3.0  ┆ … ┆ 121.0        ┆ 221.0           ┆ 147.0       ┆ SHEM_16_7  │
# │ 2016.0 ┆ 1.0   ┆ 14.0 ┆ 3.0  ┆ … ┆ 121.0        ┆ 221.0           ┆ 147.0       ┆ SHEM_16_7  │
# │ 2016.0 ┆ 1.0   ┆ 14.0 ┆ 3.0  ┆ … ┆ 121.0        ┆ 221.0           ┆ 147.0       ┆ SHEM_16_7  │
# │ 2016.0 ┆ 1.0   ┆ 14.0 ┆ 3.0  ┆ … ┆ 121.0        ┆ 221.0           ┆ 147.0       ┆ SHEM_16_7  │
# │ 2016.0 ┆ 1.0   ┆ 14.0 ┆ 3.0  ┆ … ┆ 121.0        ┆ 221.0           ┆ 147.0       ┆ SHEM_16_7  │
# │ …      ┆ …     ┆ …    ┆ …    ┆ … ┆ …            ┆ …               ┆ …           ┆ …          │
# │ 2016.0 ┆ 1.0   ┆ 14.0 ┆ 3.0  ┆ … ┆ 121.0        ┆ 221.0           ┆ 147.0       ┆ SHEM_16_7  │
# │ 2016.0 ┆ 1.0   ┆ 14.0 ┆ 3.0  ┆ … ┆ 121.0        ┆ 221.0           ┆ 147.0       ┆ SHEM_16_7  │
# │ 2016.0 ┆ 1.0   ┆ 14.0 ┆ 3.0  ┆ … ┆ 121.0        ┆ 221.0           ┆ 147.0       ┆ SHEM_16_7  │
# │ 2016.0 ┆ 1.0   ┆ 14.0 ┆ 3.0  ┆ … ┆ 121.0        ┆ 221.0           ┆ 147.0       ┆ SHEM_16_7  │
# │ 2016.0 ┆ 1.0   ┆ 14.0 ┆ 3.0  ┆ … ┆ 121.0        ┆ 221.0           ┆ 147.0       ┆ SHEM_16_7  │
# └────────┴───────┴──────┴──────┴───┴──────────────┴─────────────────┴─────────────┴────────────┘

# %% [markdown]
# Assuming each row is a WWLLN lightning event, we can drop the lightning-related columns to free up space and deduplicate. We only want the shear data for now. The lightning events are retained in the separate lightning dataset.

# %%
# Assuming each row is actually a lightning event - we don't need the lat/long/distance columns
shear_data = shear_data.drop(["second", "lat", "long", "distance_east", "distance_north", "category", "intensity_change", "trackfile_id"])

# %%
# Write out to csv again
shear_data = shear_data.to_pandas()
shear_data.to_csv("unbinned_shear_data_temp.txt", sep="\t")

# %% [markdown]
# Once again, we write out the data to a csv to free up space. Restart the kernel and run the import cell again. Next, we want to deduplicate the rows to get unique values for each minute. We'll use these to create 30-minute timebins later.

# %%
shear_data_lazy = pl.scan_csv("unbinned_shear_data_temp.txt", separator="\t")

# You can remove duplicates as you process chunks
shear_data_lazy_dedup = shear_data_lazy.unique()

# Collect the result (i.e., execute the lazy computation)
shear_data_dedup = shear_data_lazy_dedup.collect()

shear_data_dedup.head(20)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# restart kernel bc cry and try again
shear_data = pl.read_csv("unbinned_shear_data_temp.txt", separator="\t")

# %%
shear_data_dedup = shear_data.unique()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# bin the data by 30 min bins?

# %%
# Define a function to apply the 30-minute binning for each storm_code group
def add_time_bin(group):
    group['time_bin'] = group['datetime'].dt.floor('30T')
    return group

# %%
# Create a datetime column from the existing columns
# Ensure sec column is valid
shear_data['second'] = shear_data['second'].apply(lambda x: 0 if x == 60 else x)

# Create a datetime column
shear_data['datetime'] = pd.to_datetime(
    shear_data['year'].astype(str) + '-' +
    shear_data['month'].astype(str).str.zfill(2) + '-' +
    shear_data['day'].astype(str).str.zfill(2) + ' ' +
    shear_data['hour'].astype(str).str.zfill(2) + ':' +
    shear_data['min'].astype(str).str.zfill(2) + ':' +
    shear_data['second'].astype(str).str.zfill(2)
)

# Group by storm_code and apply the binning function
shear_data = shear_data.groupby('storm_code').apply(add_time_bin)

# Group by bins and get the average value per 30-minute bin
shear_data_binned = shear_data.groupby(['storm_code', 'time_bin'])
shear_data_binned = shear_data.groupby(['storm_code', 'time_bin'])[['shear_magnitude', 'shear_angle']].mean().reset_index()

shear_data_binned = shear_data_binned.sort_values(by = ['storm_code', 'time_bin'])
shear_data_binned.head()
# export both the ungrouped and grouped datasets to csv files
# locations_WWLLN_filtered_innercore.to_csv("WWLLN_innercore_w_time.csv", index=False)
# locations_WWLLN_filtered_innercore_timebin.to_csv("WWLLN_innercore_timebin_count.csv", index=False)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
